# %% [markdown]
# # 🌈 Montando um Robô Detetive!
#
# Imagine que temos um robô detetive super inteligente! Primeiro, damos para ele um monte de livros e informações (os 'Docs'). Ele corta esses livros em pedacinhos menores (o 'Split') para organizar tudo direitinho. Depois, ele guarda esses pedacinhos em um armário especial (o 'Vector Store').
#
# Quando fazemos uma pergunta para o robô, ele corre até o armário, encontra os pedacinhos de informação mais importantes (o 'Retriever') e usa essa informação para responder a nossa pergunta (o 'LLM'). É como se ele fosse um aluno esperto que estuda muito para poder responder todas as perguntas!
#
# O 'create_retrieval_chain' é como se fosse o manual de instruções para montar esse robô detetive e fazer ele funcionar direitinho!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate

# Crie um modelo de linguagem (nosso robô inteligente)
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# Crie um prompt (a pergunta que vamos fazer)
prompt = ChatPromptTemplate.from_template("Responda a esta pergunta: {pergunta}")

# Crie a chain de busca (o manual de instruções do robô)
retrieval_chain = create_retrieval_chain(llm, retriever=None, prompt=prompt)

print("Robô detetive pronto!")
