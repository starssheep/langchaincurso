# %% [markdown]
# # 🌈 Desvendando Segredos com RAG: Como Super Robôs Encontram Respostas!
#
# Imagine que temos um super robô que pode responder qualquer pergunta, mas ele só sabe o que está dentro da sua cabeça, como as coisas que você aprende na escola!
#
# Para ensinar coisas novas para o robô, precisamos de duas coisas:
#
# 1.  **Carregar Documentos (Loaders):** É como dar livros e revistas para o robô ler. Ele vai pegar todas as informações importantes desses lugares.
# 2.  **Dividir o Texto (Splitters):** Imagine que os livros são muito grandes! Precisamos cortar os livros em pedacinhos menores, como se fossem capítulos ou páginas, para o robô entender melhor e encontrar as respostas mais rápido.
#
# Depois que o robô lê e divide os textos, ele consegue responder qualquer pergunta que você fizer, usando as informações dos livros! Isso é RAG: ensinar coisas novas para o robô para ele ficar super inteligente!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import create_extraction_chain

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0.0)

schema = {
    "properties": {
        "animal": {
            "type": "string",
            "description": "Nome de um animal"
        },
        "color": {
            "type": "string",
            "description": "Cor do animal"
        }
    },
    "type": "object"
}

chain = create_extraction_chain(schema, llm)

print(chain.run("Eu vi um gato preto e um cachorro marrom."))
