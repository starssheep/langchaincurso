# %% [markdown]
# # 🌈 Pydantic: O Super-Herói dos Dados!
#
# Imagine que o Pydantic é como um robô super esperto que trabalha na escola. A escola recebe muitos brinquedos (dados) todos os dias. O trabalho do Pydantic é verificar se cada brinquedo está correto antes de deixar as crianças brincarem com ele.
#
# Por exemplo, se um brinquedo precisa de 5 pilhas, o Pydantic garante que ele realmente tenha 5 pilhas e não 4 ou 6. Se o brinquedo for um carro, ele verifica se tem rodas e não asas!
#
# No computador, o Pydantic faz a mesma coisa com os dados. Ele verifica se os números são realmente números, se os textos são realmente textos, e se tudo está no lugar certo. Se algo estiver errado, ele avisa para que possamos corrigir antes de causar problemas. Assim, o Pydantic ajuda a manter tudo organizado e funcionando bem!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0.3)

resposta = llm.invoke("Qual a capital do Brasil?")

print(resposta.content)
# Out:
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/google/api_core/_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.9.6). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...
