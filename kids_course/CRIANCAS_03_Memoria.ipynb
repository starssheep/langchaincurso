# %% [markdown]
# # 🌈 O Elefante Esquecido e o Chatbot
#
# Olá, crianças! Já viram aqueles brinquedos robôs que repetem o que a gente fala? Imagine que temos um robô muito legal que adora conversar, mas ele tem um problema: ele esquece tudo o que falamos logo depois de responder! É como um elefante que esquece onde enterrou o amendoim.
#
# Para ajudar nosso robô a lembrar, precisamos dar a ele um caderno mágico chamado 'memória'. Nesse caderno, anotamos tudo o que conversamos. Assim, da próxima vez que falarmos com ele, ele pode ler o caderno e lembrar de tudo! Isso é muito importante para ele não ficar confuso e dar respostas melhores, como um bom amiguinho que sempre lembra das nossas brincadeiras.
#
# No mundo dos computadores, usamos códigos para fazer isso. O código abaixo mostra como dar um 'caderno de memória' para o nosso robô.

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

prompt = ChatPromptTemplate.from_template("Meu nome é Nauber. Qual é o meu nome?")
chain = prompt | llm | StrOutputParser()

print(chain.invoke({}))
# Out:
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/google/api_core/_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.9.6). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...
