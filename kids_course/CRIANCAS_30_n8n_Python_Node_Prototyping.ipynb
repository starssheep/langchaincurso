# %% [markdown]
# # 🌈 Desvendando o n8n com Robôs e Peças de Lego!
#
# Imagine que o n8n é como um super robô que adora brincar de Lego! Cada peça de Lego é uma informação (como seu nome, sua idade ou sua cor favorita). Às vezes, o robô recebe uma caixa cheia de peças misturadas e precisa organizá-las antes de construir algo legal.
#
# No n8n, essas peças de Lego são chamadas de 'items'. Cada 'item' tem uma etiqueta 'json' onde guardamos os detalhes importantes.
#
# Agora, você quer dar ordens para o robô, tipo 'separe as peças vermelhas' ou 'conte quantas peças azuis tem'. Para isso, você usa um código secreto, como uma receita de bolo, que diz exatamente o que o robô deve fazer. Esse código é escrito em Python, uma linguagem que os computadores entendem!
#
# Às vezes, o robô precisa de ferramentas especiais (como uma chave de fenda) para montar as peças de Lego. Essas ferramentas são como 'pacotes' que adicionamos ao n8n para que ele possa fazer coisas ainda mais incríveis!
#
# Então, o n8n é um robô que organiza informações (os 'items') usando códigos secretos (em Python) e ferramentas especiais (os 'pacotes') para construir coisas super legais!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0.3)

prompt = PromptTemplate.from_template("Me diga uma piada curta sobre robôs: {input}")

chain = LLMChain(llm=llm, prompt=prompt)

print(chain.run("robôs engraçados"))
# Out:
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/google/api_core/_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.9.6). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...
