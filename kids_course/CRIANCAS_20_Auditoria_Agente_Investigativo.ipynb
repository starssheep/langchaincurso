# %% [markdown]
# # 🌈 Detetive de Dados: Desvendando Mistérios com Robôs!
#
# Imagine que temos um robô detetive, como um brinquedo super esperto, que ajuda a descobrir se tudo está certinho em uma empresa! Esse robô usa ferramentas especiais (como lupas mágicas) para procurar informações importantes, tipo o número de registro da empresa (CNPJ). Ele vai na Receita Federal (como se fosse a diretora da escola) e vê se tudo está OK. Se o robô encontrar algo estranho, ele avisa! Usamos um código secreto (LangChain com Gemini 2.0) para dar as instruções para o robô detetive e ele faz todo o trabalho sozinho!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import AgentExecutor, create_tool_calling_agent
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.tools import tool

@tool
def somar(a: int, b: int) -> int:
    """Soma dois números inteiros."""
    return a + b

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

tools = [somar]

prompt = ChatPromptTemplate.from_messages(
    [   
        ("system", "Você é um ajudante muito gentil e prestativo que só sabe somar."),
        ("user", "Some {a} e {b} para mim por favor."),
    ]
)

agent = create_tool_calling_agent(llm=llm, tools=tools, prompt=prompt)

agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

print(agent_executor.invoke({"a": 2, "b": 3}))
