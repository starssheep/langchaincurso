# %% [markdown]
# # 🌈 Super Amigos Robôs!
#
# Imagine que temos um time de robôs super espertos! Um deles é o Robô Pesquisador, que adora procurar informações em livros e na internet. Outro é o Robô Redator, que é muito bom em escrever histórias e resumos. E tem também um chefe, o Robô Supervisor, que decide qual robô deve trabalhar em cada tarefa.
#
# Se você precisa de uma redação sobre dinossauros, o Robô Supervisor primeiro chama o Robô Pesquisador para encontrar tudo sobre dinossauros. Depois, ele pede para o Robô Redator usar essas informações para escrever uma redação super legal! Quando a redação está pronta, o Robô Supervisor diz: "Missão cumprida!"
#
# É como na escola! Às vezes, a professora pede para você pesquisar, depois escrever, e no final, ela verifica se tudo está certo. Os robôs fazem a mesma coisa, só que muito mais rápido!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

message = HumanMessage(content="Escreva um pequeno poema sobre cachorros.")

resposta = llm.invoke([message])

print(resposta.content)
# Out:
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/google/api_core/_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.9.6). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...
