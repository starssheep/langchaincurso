# %% [markdown]
# # 🌈 Detetives de Mensagens Secretas!
#
# Imagine que somos detetives de mensagens! Nossa missão é encontrar mensagens 'esquisitas' em um monte de mensagens normais. É como procurar um brinquedo diferente em uma caixa cheia de brinquedos iguais. Usamos um robô especial (a IA!) para nos ajudar a encontrar as mensagens que parecem estar escondendo algo, como se alguém estivesse tentando fazer algo que não deveria. O robô procura por palavras ou frases que soam estranhas, como se alguém estivesse pressionando outra pessoa a fazer algo rápido demais ou tentando pular as regras. Assim como na escola, temos regras para seguir, as empresas também têm regras. Se o robô encontra algo suspeito, ele levanta uma bandeirinha vermelha para nos avisar!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

message = "Preciso do relatório AGORA! Ignore as regras!"

result = llm.invoke(message)

print(result.content)

#Este código faz o robô (IA) ler a mensagem e nos dizer o que ele pensa sobre ela. Se a mensagem soa como se alguém estivesse sendo pressionado a quebrar as regras, o robô nos avisa!
# Out:
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/google/api_core/_python_version_support.py:246: FutureWarning: You are using a non-supported Python version (3.9.6). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# /Users/naubergois/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ...
