# %% [markdown]
# # 🌈 Super-Resumo de Robôs Auditores!
#
# Imagine que somos detetives robôs numa escola! Recebemos um relatório gigante sobre tudo o que aconteceu: quem comeu o lanche de quem, quem rabiscou a parede, etc. É muita coisa pra gente ler tudo! Nossa missão é encontrar só as partes mais importantes: os 'Pontos de Atenção' (tipo, 'a parede está rabiscada!') e as 'Recomendações' (tipo, 'vamos limpar a parede juntos!'). Usamos uma ferramenta mágica que nem um aspirador de pó gigante pra sugar só o que importa e criar um resumo super curto para o diretor (que é a 'alta gestão'). Assim, ele não precisa ler o relatório todinho, só o que é mais importante para resolver os problemas!

# %%
# Configuração Inicial
import os
from dotenv import load_dotenv

# Carregando chaves do arquivo central de scripts
load_dotenv(r'/Users/naubergois/langchaincurso/scripts/.env')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.summarize import load_summarize_chain

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0.0)
chain = load_summarize_chain(llm, chain_type="stuff")

long_document = "Este é um relatório longo sobre a bagunça na sala de aula. João jogou papel, Maria derrubou tinta, e Pedro comeu o giz. Precisamos limpar tudo e ensinar as crianças a serem mais organizadas."

print(chain.run([long_document]))
